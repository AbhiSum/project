# %%
Data = [line.replace('\n', '') for line in open('players.csv', 'rt', encoding = "utf-8").readlines()]
print(Data)
head = Data.pop(0)
print(head)
# Out:
# [',Name,Age,Nationality,Overall,Potential,Club,Value,Wage,Special,Acceleration,Aggression,Agility,Balance,Ball control,Composure,Crossing,Curve,Dribbling,Finishing,Free kick accuracy,GK diving,GK handling,GK kicking,GK positioning,GK reflexes,Heading accuracy,Interceptions,Jumping,Long passing,Long shots,Marking,Penalties,Positioning,Reactions,Short passing,Shot power,Sliding tackle,Sprint speed,Stamina,Standing tackle,Strength,Vision,Volleys,ID,Preferred Positions', '0,A. Areola,24,France,79,86,Paris Saint-Germain,€13M,€54K,1266,54,26,53,58,22,35,20,16,12,19,16,81,77,70,74,83,14,23,59,32,14,19,25,17,76,41,25,12,52,28,18,80,34,16,193105,GK ', '1,A. Ayew,27,Ghana,79,79,West Ham United,€13M,€110K,2086,76,78,86,81,79,74,77,74,78,73,57,10,6,12,7,15,76,52,88,71,75,49,71,79,75,77,75,57,75,86,60,71,75,65,176571,CAM ST RM ', '2,A. Barzagli,36,Italy,85,85,Juventus,€5M,€105K,1750,64,70,51,64,65,82,40,50,64,21,31,4,2,4,2,4,72,92,85,65,39,90,60,28,80,65,54,88,76,46,90,87,62,35,137186,CB ', '3,A.
# ...

# %%
def sorter(record):
    line = record.split(',')
    rec = (line[1], line[4], line[5])
    name, overall, potential = rec
    return(float(overall), float(potential))

Data.sort(key = sorter, reverse = True)

for record in Data: 
    line = record.split(',')
    print(line[1])
# Out:
# Cristiano Ronaldo
# L. Messi
# Neymar
# L. Suárez
# M. Neuer
# R. Lewandowski
# De Gea
# E. Hazard
# G. Higuaín
# Sergio Ramos
# T. Kroos
# K. De Bruyne
# T. Courtois
# A. Sánchez
# G. Bale
# G. Buffon
# G. Chiellini
# L. Modrić
# S. Agüero
# J. Oblak
# P. Dybala
# A. Griezmann
# Thiago
# A. Robben
# D. Godín
# H. Lloris
# J. Boateng
# L. Bonucci
# M. Özil
# M. Hummels
# P. Aubameyang
# Thiago Silva
# Z. Ibrahimović
# P. Pogba
# C. Eriksen
# M. Verratti
# N. Kanté
# A. Vidal
# David Silva
# E. Cavani
# I. Rakitić
# Iniesta
# M. Hamšík
# Marcelo
# Piqué
# S. Handanovič
# H. Kane
# Isco
# R. Lukaku
# Coutinho
# J. Rodríguez
# Alex Sandro
# D. Alaba
# T. Alderweireld
# Cesc Fàbregas
# D. Mertens
# David Luiz
# Diego Costa
# F. Ribéry
# Javi Martínez
# K. Benzema
# M. Reus
# Miranda
# P. Čech
# Pepe
# R. Nainggolan
# Sergio Busquets
# Sokratis
# T. Müller
# R. Varane
# Y. Carrasco
# Casemiro
# M. ter Stegen
# A. Lacazette
# B. Leno
# Azpilicueta
# I. Gündoğan
# L. Insigne
# M. Pjanić
# ...
